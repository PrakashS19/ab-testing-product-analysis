# %%
import pandas as pd
from statsmodels.stats.proportion import proportions_ztest

# %%
df = pd.read_csv("ab_test_data.csv")

# %%
df.head()
# Out:
#    user_id    group signup_date  activated activation_date  revenue
# 0        1  Variant  23-06-2024          0             NaN        0
# 1        2  Control  10-06-2024          0             NaN        0
# 2        6  Control  01-01-2024          0             NaN        0
# 3        7  Control  15-03-2024          0             NaN        0
# 4       10  Variant  22-01-2024          0             NaN        0

# %%
summary = df.groupby("group").agg(
    users=("user_id", "count"),
    conversions=("activated", "sum")
).reset_index()

print(summary)
# Out:
#      group  users  conversions
# 0  Control   4969         1446
# 1  Variant   5031         1998

# %%
# conversions
count = summary["conversions"].values

# total users
nobs = summary["users"].values

# run test
stat, p_value = proportions_ztest(count, nobs)

print("Z-stat:", stat)
print("P-value:", p_value)
# Out:
# Z-stat: -11.167685639498288
# P-value: 5.869017504517015e-29
